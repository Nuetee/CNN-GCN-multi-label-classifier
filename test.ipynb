# %%
import pickle
import gzip

# %%
# import pandas as pd
# import shutil
# import os

# with open("test", "rb") as file:
#     artworks = pickle.load(file)

# src_folder = "database_all"
# dst_folder = "database_test"

# for file_name in artworks["File"]:
#     src_path = os.path.join(src_folder, file_name)
#     dst_path = os.path.join(dst_folder, file_name)
#     shutil.copy(src_path, dst_path)

# %%
with open('./cnngcn_val_precision-epoch30.pickle', 'rb') as f:
	cnngcn_val_precision = pickle.load(f)  # 단 한줄씩 읽어옴
cnngcn_val_precision
# Out:
# [0.045034848153591156,
#  0.08574718236923218,
#  0.1557948887348175,
#  0.1514575034379959,
#  0.23008324205875397,
#  0.23053131997585297,
#  0.25476551055908203,
#  0.3127255141735077,
#  0.3136803209781647,
#  0.3230920732021332,
#  0.3285601735115051,
#  0.33935749530792236,
#  0.3295743763446808,
#  0.3310507833957672,
#  0.3454027473926544,
#  0.34915629029273987,
#  0.34895938634872437,
#  0.34602096676826477,
#  0.34664231538772583,
#  0.3489930331707001,
#  0.34407034516334534,
#  0.35089311003685,
#  0.3489331603050232,
#  0.3477728068828583,
#  0.34589099884033203,
#  0.3425978720188141,
#  0.34617215394973755,
#  0.3487035036087036,
#  0.3484259843826294]

# %%
with open('./variables/cnngcn_3_1_5_1_gsc_elu_false_2_0-50epoch-test/cnngcn_train_loss-epoch50.pickle', 'rb') as f:
	cnngcn_train_loss = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/cnngcn_3_1_5_1_gsc_elu_false_2_0-50epoch-test/cnngcn_train_precision-epoch50.pickle', 'rb') as f:
	cnngcn_train_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/cnngcn_3_1_5_1_gsc_elu_false_2_0-50epoch-test/cnngcn_train_recall-epoch50.pickle', 'rb') as f:
	cnngcn_train_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/cnngcn_3_1_5_1_gsc_elu_false_2_0-50epoch-test/cnngcn_train_f1s-epoch50.pickle', 'rb') as f:
	cnngcn_train_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴

with open('./variables/cnngcn_3_1_5_1_gsc_elu_false_2_0-50epoch-test/cnngcn_val_loss-epoch50.pickle', 'rb') as f:
	cnngcn_val_loss = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/cnngcn_3_1_5_1_gsc_elu_false_2_0-50epoch-test/cnngcn_val_precision-epoch50.pickle', 'rb') as f:
	cnngcn_val_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/cnngcn_3_1_5_1_gsc_elu_false_2_0-50epoch-test/cnngcn_val_recall-epoch50.pickle', 'rb') as f:
	cnngcn_val_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/cnngcn_3_1_5_1_gsc_elu_false_2_0-50epoch-test/cnngcn_val_f1s-epoch50.pickle', 'rb') as f:
	cnngcn_val_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴

with open('./variables/resnet50-50epochs-test/resnet50_train_loss-epoch50.pickle', 'rb') as f:
	resnet_train_loss = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/resnet50-50epochs-test/resnet50_train_precision-epoch50.pickle', 'rb') as f:
	resnet_train_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/resnet50-50epochs-test/resnet50_train_recall-epoch50.pickle', 'rb') as f:
	resnet_train_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/resnet50-50epochs-test/resnet50_train_f1s-epoch50.pickle', 'rb') as f:
	resnet_train_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴

with open('./variables/resnet50-50epochs-test/resnet50_val_loss-epoch50.pickle', 'rb') as f:
	resnet_val_loss = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/resnet50-50epochs-test/resnet50_val_precision-epoch50.pickle', 'rb') as f:
	resnet_val_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/resnet50-50epochs-test/resnet50_val_recall-epoch50.pickle', 'rb') as f:
	resnet_val_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/resnet50-50epochs-test/resnet50_val_f1s-epoch50.pickle', 'rb') as f:
	resnet_val_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴

# %%
import matplotlib.pyplot as plt
import matplotlib.style as style

plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_train_loss))
cnngcn_y = cnngcn_train_loss
resnet_x = range(len(resnet_train_loss))
resnet_y = resnet_train_loss
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn train loss')
plt.plot(resnet_x, resnet_y, label='resnet50 train loss')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('train loss')
plt.title('Train loss')
plt.show()

# %%
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_train_precision))
cnngcn_y = cnngcn_train_precision
resnet_x = range(len(resnet_train_precision))
resnet_y = resnet_train_precision
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn train precision')
plt.plot(resnet_x, resnet_y, label='resnet50 train precision')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('train precision')
plt.title('Train precision')
plt.show()

# %%
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_train_recall))
cnngcn_y = cnngcn_train_recall
resnet_x = range(len(resnet_train_recall))
resnet_y = resnet_train_recall
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn train recall')
plt.plot(resnet_x, resnet_y, label='resnet50 train recall')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('train recall')
plt.title('Train recall')
plt.show()

# %%
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_train_f1_score))
cnngcn_y = cnngcn_train_f1_score
resnet_x = range(len(resnet_train_f1_score))
resnet_y = resnet_train_f1_score
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn train f1 score')
plt.plot(resnet_x, resnet_y, label='resnet50 train f1 score')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('train f1 score')
plt.title('Train f1 score')
plt.show()

# %%
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_val_loss))
cnngcn_y = cnngcn_val_loss
resnet_x = range(len(resnet_val_loss))
resnet_y = resnet_val_loss
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn val loss')
plt.plot(resnet_x, resnet_y, label='resnet50 val loss')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('val loss')
plt.title('Val loss')
plt.show()

# %%
cnngcn_val_loss
# Out:
# [0.14397754274290195,
#  0.13410158185450077,
#  0.12923493145713144,
#  0.13477016367924124,
#  0.12618472153510407,
#  0.13041416897667252,
#  0.1282189365836882,
#  0.11204517678942337,
#  0.11092322595214134,
#  0.11113891709900968,
#  0.111757335865468,
#  0.11606512253840567,
#  0.11608645989196768,
#  0.12098665812766878,
#  0.11898482748060013,
#  0.11952931927540167,
#  0.12138882253513147,
#  0.12044641556722059,
#  0.1211893649462139,
#  0.1219643473107525,
#  0.12308488109567325,
#  0.12239420284556396,
#  0.12190683315468781,
#  0.12293193609483781,
#  0.12207596166701826,
#  0.12287845556848398,
#  0.12244989040767584,
#  0.12384325472947681,
#  0.12259145114321271,
#  0.12201714730144435,
#  0.12231227548483288,
#  0.1238518645686488,
#  0.12248706296271189,
#  0.12276162515872761,
#  0.12331748624371536,
#  0.12221978883959224,
#  0.12330441285969305,
#  0.12200228910588153,
#  0.12239348715536352,
#  0.12288137005813068,
#  0.12191159731105303,
# ...

# %%
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_val_precision))
cnngcn_y = cnngcn_val_precision
resnet_x = range(len(resnet_val_precision))
resnet_y = resnet_val_precision
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn val precision')
plt.plot(resnet_x, resnet_y, label='resnet50 val precision')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('val precision')
plt.title('Val precision')
plt.show()

# %%
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_val_recall))
cnngcn_y = cnngcn_val_recall
resnet_x = range(len(resnet_val_recall))
resnet_y = resnet_val_recall
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn val recall')
plt.plot(resnet_x, resnet_y, label='resnet50 val recall')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('val recall')
plt.title('Val recall')
plt.show()

# %%
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_val_f1_score))
cnngcn_y = cnngcn_val_f1_score
resnet_x = range(len(resnet_val_f1_score))
resnet_y = resnet_val_f1_score
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn val f1 score')
plt.plot(resnet_x, resnet_y, label='resnet50 val f1 score')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('val f1 score')
plt.title('Val f1 score')
plt.show()

# %%
with open('./variables/main/cnngcn-4/cnngcn_train_loss-epoch30.pickle', 'rb') as f:
	cnngcn_train_loss = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/cnngcn-4/cnngcn_train_precision-epoch30.pickle', 'rb') as f:
	cnngcn_train_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/cnngcn-4/cnngcn_train_recall-epoch30.pickle', 'rb') as f:
	cnngcn_train_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/cnngcn-4/cnngcn_train_f1s-epoch30.pickle', 'rb') as f:
	cnngcn_train_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴

with open('./variables/main/cnngcn-4/cnngcn_w_train_precision-epoch30.pickle', 'rb') as f:
	cnngcn_w_train_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/cnngcn-4/cnngcn_w_train_recall-epoch30.pickle', 'rb') as f:
	cnngcn_w_train_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/cnngcn-4/cnngcn_w_train_f1s-epoch30.pickle', 'rb') as f:
	cnngcn_w_train_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴

with open('./variables/main/cnngcn-4/cnngcn_val_loss-epoch30.pickle', 'rb') as f:
	cnngcn_val_loss = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/cnngcn-4/cnngcn_val_precision-epoch30.pickle', 'rb') as f:
	cnngcn_val_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/cnngcn-4/cnngcn_val_recall-epoch30.pickle', 'rb') as f:
	cnngcn_val_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/cnngcn-4/cnngcn_val_f1s-epoch30.pickle', 'rb') as f:
	cnngcn_val_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴

with open('./variables/main/cnngcn-4/cnngcn_w_val_precision-epoch30.pickle', 'rb') as f:
	cnngcn_w_val_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/cnngcn-4/cnngcn_w_val_recall-epoch30.pickle', 'rb') as f:
	cnngcn_w_val_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/cnngcn-4/cnngcn_w_val_f1s-epoch30.pickle', 'rb') as f:
	cnngcn_w_val_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴

with open('./variables/main/resnet50-2/resnet50_train_loss-epoch50.pickle', 'rb') as f:
	resnet_train_loss = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/resnet50-2/resnet50_train_precision-epoch50.pickle', 'rb') as f:
	resnet_train_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/resnet50-2/resnet50_train_recall-epoch50.pickle', 'rb') as f:
	resnet_train_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/resnet50-2/resnet50_train_f1s-epoch50.pickle', 'rb') as f:
	resnet_train_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴

with open('./variables/main/resnet50-2/resnet50_w_train_precision-epoch50.pickle', 'rb') as f:
	resnet_w_train_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/resnet50-2/resnet50_w_train_recall-epoch50.pickle', 'rb') as f:
	resnet_w_train_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/resnet50-2/resnet50_w_train_f1s-epoch50.pickle', 'rb') as f:
	resnet_w_train_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴

with open('./variables/main/resnet50-2/resnet50_val_loss-epoch50.pickle', 'rb') as f:
	resnet_val_loss = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/resnet50-2/resnet50_val_precision-epoch50.pickle', 'rb') as f:
	resnet_val_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/resnet50-2/resnet50_val_recall-epoch50.pickle', 'rb') as f:
	resnet_val_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/resnet50-2/resnet50_val_f1s-epoch50.pickle', 'rb') as f:
	resnet_val_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴

with open('./variables/main/resnet50-2/resnet50_w_val_precision-epoch50.pickle', 'rb') as f:
	resnet_w_val_precision = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/resnet50-2/resnet50_w_val_recall-epoch50.pickle', 'rb') as f:
	resnet_w_val_recall = pickle.load(f)  # 단 한줄씩 읽어옴
with open('./variables/main/resnet50-2/resnet50_w_val_f1s-epoch50.pickle', 'rb') as f:
	resnet_w_val_f1_score = pickle.load(f)  # 단 한줄씩 읽어옴
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 28
#      26 with open('./variables/main/cnngcn-4/cnngcn_w_val_precision-epoch30.pickle', 'rb') as f:
#      27 	cnngcn_w_val_precision = pickle.load(f)  # 단 한줄씩 읽어옴
# ---> 28 with open('./variables/main/cnngcn-4/cnngcn_w_val_recall-epoch30.pickle', 'rb') as f:
#      29 	cnngcn_w_val_recall = pickle.load(f)  # 단 한줄씩 읽어옴
#      30 with open('./variables/main/cnngcn-4/cnngcn_w_val_f1s-epoch30.pickle', 'rb') as f:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_train_loss))
cnngcn_y = cnngcn_train_loss
resnet_x = range(len(resnet_train_loss))
resnet_y = resnet_train_loss
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn train loss')
plt.plot(resnet_x, resnet_y, label='resnet50 train loss')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('train loss')
plt.title('Train loss')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_train_precision))
cnngcn_y = cnngcn_train_precision
resnet_x = range(len(resnet_train_precision))
resnet_y = resnet_train_precision
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn train precision')
plt.plot(resnet_x, resnet_y, label='resnet50 train precision')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('train precision')
plt.title('Train precision')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_train_recall))
cnngcn_y = cnngcn_train_recall
resnet_x = range(len(resnet_train_recall))
resnet_y = resnet_train_recall
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn train recall')
plt.plot(resnet_x, resnet_y, label='resnet50 train recall')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('train recall')
plt.title('Train recall')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_train_f1_score))
cnngcn_y = cnngcn_train_f1_score
resnet_x = range(len(resnet_train_f1_score))
resnet_y = resnet_train_f1_score
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn train f1-score')
plt.plot(resnet_x, resnet_y, label='resnet50 train f1-score')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('train f1-score')
plt.title('Train f1-score')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_val_loss))
cnngcn_y = cnngcn_val_loss
resnet_x = range(len(resnet_val_loss))
resnet_y = resnet_val_loss
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn val loss')
plt.plot(resnet_x, resnet_y, label='resnet50 val loss')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('val loss')
plt.title('Val loss')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_val_precision))
cnngcn_y = cnngcn_val_precision
resnet_x = range(len(resnet_val_precision))
resnet_y = resnet_val_precision
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn val precision')
plt.plot(resnet_x, resnet_y, label='resnet50 val precision')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('val precision')
plt.title('Val precision')
plt.show()

# %%
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_val_recall))
cnngcn_y = cnngcn_val_recall
resnet_x = range(len(resnet_val_recall))
resnet_y = resnet_val_recall
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn val recall')
plt.plot(resnet_x, resnet_y, label='resnet50 val recall')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('val recall')
plt.title('Val recall')
plt.show()

# %%
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_val_f1_score))
cnngcn_y = cnngcn_val_f1_score
resnet_x = range(len(resnet_val_f1_score))
resnet_y = resnet_val_f1_score
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn val f1-score')
plt.plot(resnet_x, resnet_y, label='resnet50 val f1-score')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('val f1-score')
plt.title('Val f1-score')
plt.show()

# %%
import numpy as np
original = sum(resnet_val_f1_score[18:28])/10
weighted = sum(resnet_w_val_f1_score[18:28])/10

print(original)
print(weighted)
print(weighted/original)
# Out:
# 0.5482105851173401
# 0.5498300492763519
# 1.002954091371047

# %%
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_val_recall))
cnngcn_y = cnngcn_val_recall
resnet_x = range(len(cnngcn_w_val_recall))
resnet_y = cnngcn_w_val_recall
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn val precision')
plt.plot(resnet_x, resnet_y, label='cnngcn weighted val precision')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('precision')
plt.title('cnngcn val precision')
plt.show()

# %%
plt.figure(figsize=(6, 6))
cnngcn_x = range(len(cnngcn_train_recall))
cnngcn_y = cnngcn_train_recall
resnet_x = range(len(cnngcn_w_train_recall))
resnet_y = cnngcn_w_train_recall
plt.plot(cnngcn_x, cnngcn_y, label='cnngcn train recall')
plt.plot(resnet_x, resnet_y, label='cnngcn weighted train recall')
plt.legend(loc='best')
plt.xlabel('epochs')
plt.ylabel('recall')
plt.title('cnngcn train recall')
plt.show()
